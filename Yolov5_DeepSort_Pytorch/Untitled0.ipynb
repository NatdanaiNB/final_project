# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.random import RandomState

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\sydney\\project_y4\\yolov5\\runs\\train\exp10\\results.csv')

# %%
a = df['     metrics/mAP_0.5']

# %%
b = df['      train/box_loss']

# %%
c = df['        val/box_loss']

# %%
plt.figure(figsize=(12,7))
plt.plot(b, color ='g')
plt.plot(c, color ='r')
plt.legend(["train", "val"])
plt.title('Training and Validation Box Loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
b = df['      train/obj_loss']
c = df['        val/obj_loss']
plt.figure(figsize=(12,7))
plt.plot(b, color ='g')
plt.plot(c, color ='r')
plt.legend(["train", "val"])
plt.title('Training and Validation Object Loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
b = df['      train/cls_loss']
c = df['        val/cls_loss']
plt.figure(figsize=(12,7))
plt.plot(b, color ='g')
plt.plot(c, color ='r')
plt.legend(["train", "val"])
plt.title('Training and Validation Class Loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
a = df['     metrics/mAP_0.5']
plt.figure(figsize=(12,7))
plt.plot(a)

plt.title('mAP at 0.5')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
a = df['metrics/mAP_0.5:0.95']
plt.figure(figsize=(12,7))
plt.plot(a)

plt.title('mAP at 0.5:095')
plt.xlabel('epoch')
plt.ylabel('value')
plt.savefig('allclass_mAPauc.jpg')
plt.show()

# %%
a.sort_values()
# Out:
# 0     0.10720
# 3     0.30200
# 4     0.41129
# 1     0.42024
# 2     0.44428
#        ...
# 79    0.72182
# 83    0.72244
# 63    0.72359
# 82    0.72385
# 80    0.72575
# Name: metrics/mAP_0.5:0.95, Length: 181, dtype: float64
